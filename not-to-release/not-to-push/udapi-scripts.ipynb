# %% [markdown]
# # Import

# %%
import udapi

# %% [markdown]
# # Classes

# %%
class FilterList(list):
    def filter(self, **kwargs):
        matched_tokens = []
        for tb, node in self:
            found = True
            for k, v in kwargs.items():
                if isinstance(v, str):
                    if k in node.feats.keys():
                        if node.feats[k] != v:
                            found = False
                            break
                    elif hasattr(node, k):
                        if getattr(node, k) != v:
                            found = False
                            break
                    else:
                        if v is not None:
                            found = False
                            break
                elif callable(v):
                    if not v(node):
                        found = False
                        break
                else:
                    found = False    
            if found:
                matched_tokens.append((tb, node))
        return matched_tokens
    
    def content(self, address=False, form=True, lemma=False, upos=False, deprel=False, feats=False, text=False, treebank=False, sorting_fn=lambda node: node[1].form.lower()):
        output = list()
        for tb, node in sorted(self, key=sorting_fn):
            line = ''
            line += f"id='{node.address()}'" + '\t' if address else ''
            line += f"treebank='{tb}'" + '\t' if treebank else ''
            line += f"form='{node.form}'" + '\t' if form else ''
            line += f"lemma='{node.lemma}'" + '\t' if lemma else ''
            line += f"upos='{node.upos}'" + '\t' if upos else ''
            line += f"deprel='{node.deprel}'" + '\t' if deprel else ''
            line += f"feats='{node.feats.__str__()}'" + '\t' if feats else ''
            line += f"text='{node.root.compute_text()}'" + '\t' if text else ''
            
            if line not in output:
                output.append(line)
        
        return output
        

class Treebanks:
    def __init__(self, treebanks) -> None:
        self.treebanks = treebanks
        for key, tb in self.treebanks.items():
            setattr(self, key, tb)

    
    @property
    def nodes(self):
        for key, tb in self.treebanks.items():
            for node in tb.nodes:
                yield key, node

    def filter(self, **kwargs):
        matched_tokens = FilterList()
        for tb, node in self.nodes:
            found = True
            for k, v in kwargs.items():
                if isinstance(v, str):
                    if k in node.feats.keys():
                        if node.feats[k] != v:
                            found = False
                            break
                    elif hasattr(node, k):
                        if getattr(node, k) != v:
                            found = False
                            break
                    else:
                        if v is not None:
                            found = False
                            break
                elif callable(v):
                    if not v(node):
                        found = False
                        break
                else:
                    found = False    
            if found:
                matched_tokens.append((tb, node))
        return matched_tokens

# %% [markdown]
# # Loading Treebanks

# %%
# talbanken_path = '/home/norrman/GitHub/UD_Swedish-Talbanken/not-to-release/output/temp/sv5.conllu'
# pud_path = '/home/norrman/GitHub/UD_Swedish-Talbanken/not-to-release/pud/sv_pud-ud-test.conllu'
# lines_path_train = '/home/norrman/GitHub/UD_Swedish-Talbanken/not-to-release/lines/sv_lines-ud-train.conllu'
# lines_path_dev = '/home/norrman/GitHub/UD_Swedish-Talbanken/not-to-release/lines/sv_lines-ud-dev.conllu'
# lines_path_test = '/home/norrman/GitHub/UD_Swedish-Talbanken/not-to-release/lines/sv_lines-ud-test.conllu'


talbanken_path = '/home/norrman/GitHub/UD_Swedish-Talbanken/not-to-release/output/temp/test1.conllu'
pud_path = '/home/norrman/GitHub/UD_Swedish-Talbanken/not-to-release/pud/test1.conllu'
lines_path_train = '/home/norrman/GitHub/UD_Swedish-Talbanken/not-to-release/lines/test1_train.conllu'
lines_path_dev = '/home/norrman/GitHub/UD_Swedish-Talbanken/not-to-release/lines/test1_dev.conllu'
lines_path_test = '/home/norrman/GitHub/UD_Swedish-Talbanken/not-to-release/lines/test1_test.conllu'

talbanken_data = udapi.Document(talbanken_path)
pud_data = udapi.Document(pud_path)
lines_data_train = udapi.Document(lines_path_train)
lines_data_dev = udapi.Document(lines_path_dev)
lines_data_test = udapi.Document(lines_path_test)

treebanks = Treebanks({'talbanken': talbanken_data, 'pud': pud_data, 'lines_dev': lines_data_dev, 'lines_test': lines_data_test, 'lines_test': lines_data_train})

# %% [markdown]
# # Testing Loads

# %%
for node in treebanks.nodes:
    print(node)
    break
# Out:
# ('talbanken', Node<sv-ud-train-1#1, Individuell>)

# %%
for node in treebanks.lines_dev.nodes:
    print(node)
    break
# Out:
# <sv_lines-ud-dev-doc1-3177#1, När>

# %%
matches = treebanks.filter(upos='ADJ',
                           VerbForm='Part',
                           func1=lambda node: node.parent.lemma == 'bli' or any(child.lemma == 'bli' for child in node.children))
print(*matches.content(lemma=True,
                       treebank=True,
                       sorting_fn=lambda node: node[1].lemma[::-1]), sep='\n')
# Out:
# treebank='talbanken'	form='avtrubbade'	lemma='avtrubbad'
# treebank='pud'	form='avskedad'	lemma='avskedad'
# treebank='pud'	form='dödade'	lemma='dödad'
# treebank='pud'	form='förbluffad'	lemma='förbluffad'
# treebank='pud'	form='tvingade'	lemma='tvingad'
# treebank='pud'	form='förälskad'	lemma='förälskad'
# treebank='lines_test'	form='förälskad'	lemma='förälskad'
# treebank='pud'	form='delat'	lemma='delad'
# treebank='lines_test'	form='glad'	lemma='glad'
# treebank='lines_test'	form='jätteglad'	lemma='jätteglad'
# treebank='pud'	form='filmad'	lemma='filmad'
# treebank='talbanken'	form='komplicerat'	lemma='komplicerad'
# treebank='pud'	form='komplicerad'	lemma='komplicerad'
# treebank='talbanken'	form='deprimerad'	lemma='deprimerad'
# treebank='lines_dev'	form='generad'	lemma='generad'
# treebank='lines_test'	form='generad'	lemma='generad'
# treebank='talbanken'	form='intresserad'	lemma='intresserad'
# treebank='talbanken'	form='irriterad'	lemma='irriterad'
# treebank='pud'	form='irriterad'	lemma='irriterad'
# treebank='pud'	form='besegrad'	lemma='besegrad'
# treebank='talbanken'	form='förtretad'	lemma='förtretad'
# treebank='pud'	form='intervjuad'	lemma='intervjuad'
# treebank='pud'	form='färdigställt'	lemma='färdigställd'
# treebank='pud'	form='såld'	lemma='såld'
# treebank='pud'	form='igenkänd'	lemma='igenkänd'
# treebank='talbanken'	form='vanebildande'	lemma='vanebildande'
# treebank='talbanken'	form='framträdande'	lemma='framträdande'
# treebank='talbanken'	form='följande'	lemma='följande'
# treebank='talbanken'	form='självförsörjande'	lemma='självförsörjande'
# treebank='talbanken'	form='tillfredsställande'	lemma='tillfredsställande'
# treebank='pud'	form='medkännande'	lemma='medkännande'
# treebank='talbanken'	form='varierande'	lemma='varierande'
# treebank='talbanken'	form='stimulerande'	lemma='stimulerande'
# treebank='talbanken'	form='avgörande'	lemma='avgörande'
# treebank='pud'	form='bitande'	lemma='bitande'
# treebank='talbanken'	form='omfattande'	lemma='omfattande'
# treebank='talbanken'	form='sittande'	lemma='sittande'
# treebank='lines_test'	form='havande'	lemma='havande'
# treebank='lines_test'	form='levande'	lemma='levande'
# treebank='talbanken'	form='beroende'	lemma='beroende'
# treebank='talbanken'	form='bestående'	lemma='bestående'
# treebank='talbanken'	form='tvungna'	lemma='tvungen'
# treebank='pud'	form='tvungen'	lemma='tvungen'
# treebank='pud'	form='skjuten'	lemma='skjuten'
# treebank='pud'	form='genskjutna'	lemma='genskjuten'
# treebank='talbanken'	form='uttryckt'	lemma='uttryckt'
# treebank='talbanken'	form='märkt'	lemma='märkt'

# %%
treebanks.filter()
# Out:
# [('talbanken', Node<sv-ud-train-1#1, Individuell>),
#  ('talbanken', Node<sv-ud-train-1#2, beskattning>),
#  ('talbanken', Node<sv-ud-train-1#3, av>),
#  ('talbanken', Node<sv-ud-train-1#4, arbetsinkomster>),
#  ('talbanken', Node<sv-ud-train-2#1, Genom>),
#  ('talbanken', Node<sv-ud-train-2#2, skattereformen>),
#  ('talbanken', Node<sv-ud-train-2#3, införs>),
#  ('talbanken', Node<sv-ud-train-2#4, individuell>),
#  ('talbanken', Node<sv-ud-train-2#5, beskattning>),
#  ('talbanken', Node<sv-ud-train-2#6, (>),
#  ('talbanken', Node<sv-ud-train-2#7, särbeskattning>),
#  ('talbanken', Node<sv-ud-train-2#8, )>),
#  ('talbanken', Node<sv-ud-train-2#9, av>),
#  ('talbanken', Node<sv-ud-train-2#10, arbetsinkomster>),
#  ('talbanken', Node<sv-ud-train-2#11, .>),
#  ('talbanken', Node<sv-ud-train-3#1, Det>),
#  ('talbanken', Node<sv-ud-train-3#2, innebär>),
#  ('talbanken', Node<sv-ud-train-3#3, bl.a.>),
#  ('talbanken', Node<sv-ud-train-3#4, att>),
#  ('talbanken', Node<sv-ud-train-3#5, endast>),
#  ('talbanken', Node<sv-ud-train-3#6, en>),
#  ('talbanken', Node<sv-ud-train-3#7, skatteskala>),
#  ('talbanken', Node<sv-ud-train-3#8, kommer>),
#  ('talbanken', Node<sv-ud-train-3#9, att>),
#  ('talbanken', Node<sv-ud-train-3#10, finnas>),
#  ('talbanken', Node<sv-ud-train-3#11, för>),
#  ('talbanken', Node<sv-ud-train-3#12, beräkning>),
#  ('talbanken', Node<sv-ud-train-3#13, av>),
#  ('talbanken', Node<sv-ud-train-3#14, statlig>),
#  ('talbanken', Node<sv-ud-train-3#15, inkomstskatt>),
#  ('talbanken', Node<sv-ud-train-3#16, .>),
#  ('talbanken', Node<sv-ud-train-4#1, Den>),
#  ('talbanken', Node<sv-ud-train-4#2, blir>),
#  ('talbanken', Node<sv-ud-train-4#3, gemensam>),
#  ('talbanken', Node<sv-ud-train-4#4, för>),
#  ('talbanken', Node<sv-ud-train-4#5, alla>),
#  ('talbanken', Node<sv-ud-train-4#6, inkomsttagare>),
#  ('talbanken', Node<sv-ud-train-4#7, oavsett>),
#  ('talbanken', Node<sv-ud-train-4#8, civilstånd>),
#  ('talbanken', Node<sv-ud-train-4#9, .>),
#  ('talbanken', Node<sv-ud-train-5#1, Den>),
#  ('talbanken', Node<sv-ud-train-5#2, gäller>),
#  ('talbanken', Node<sv-ud-train-5#3, även>),
#  ('talbanken', Node<sv-ud-train-5#4, för>),
#  ('talbanken', Node<sv-ud-train-5#5, oskifta>),
#  ('talbanken', Node<sv-ud-train-5#6, dödsbon>),
#  ('talbanken', Node<sv-ud-train-5#7, och>),
#  ('talbanken', Node<sv-ud-train-5#8, familjestiftelser>),
#  ('talbanken', Node<sv-ud-train-5#9, .>),
#  ('talbanken', Node<sv-ud-train-6#1, De>),
#  ('talbanken', Node<sv-ud-train-6#2, inkomster>),
#  ('talbanken', Node<sv-ud-train-6#3, som>),
#  ('talbanken', Node<sv-ud-train-6#4, på>),
#  ('talbanken', Node<sv-ud-train-6#5, detta>),
#  ('talbanken', Node<sv-ud-train-6#6, sätt>),
#  ('talbanken', Node<sv-ud-train-6#7, beskattas>),
#  ('talbanken', Node<sv-ud-train-6#8, individuellt>),
#  ('talbanken', Node<sv-ud-train-6#9, kallas>),
#  ('talbanken', Node<sv-ud-train-6#10, A-inkomster>),
#  ('talbanken', Node<sv-ud-train-6#11, .>),
#  ('talbanken', Node<sv-ud-train-7#1, Dessa>),
#  ('talbanken', Node<sv-ud-train-7#2, inkomster>),
#  ('talbanken', Node<sv-ud-train-7#3, är>),
#  ('talbanken', Node<sv-ud-train-7#4, *>),
#  ('talbanken', Node<sv-ud-train-7#5, inkomst>),
#  ('talbanken', Node<sv-ud-train-7#6, av>),
#  ('talbanken', Node<sv-ud-train-7#7, tjänst>),
#  ('talbanken', Node<sv-ud-train-7#8, ->),
#  ('talbanken', Node<sv-ud-train-7#9, lön>),
#  ('talbanken', Node<sv-ud-train-7#10, ,>),
#  ('talbanken', Node<sv-ud-train-7#11, pension>),
#  ('talbanken', Node<sv-ud-train-7#12, ,>),
#  ('talbanken', Node<sv-ud-train-7#13, livränta>),
#  ('talbanken', Node<sv-ud-train-7#14, ,>),
#  ('talbanken', Node<sv-ud-train-7#15, undantagsförmåner>),
#  ('talbanken', Node<sv-ud-train-7#16, och>),
#  ('talbanken', Node<sv-ud-train-7#17, övrig>),
#  ('talbanken', Node<sv-ud-train-7#18, tjänsteinkomst>),
#  ('talbanken', Node<sv-ud-train-7#19, .>),
#  ('talbanken', Node<sv-ud-train-7#20, (>),
#  ('talbanken', Node<sv-ud-train-7#21, Undantag>),
#  ('talbanken', Node<sv-ud-train-7#22, :>),
#  ('talbanken', Node<sv-ud-train-7#23, periodiskt>),
#  ('talbanken', Node<sv-ud-train-7#24, understöd>),
#  ('talbanken', Node<sv-ud-train-7#25, eller>),
#  ('talbanken', Node<sv-ud-train-7#26, därmed>),
#  ('talbanken', Node<sv-ud-train-7#27, jämförlig>),
#  ('talbanken', Node<sv-ud-train-7#28, periodisk>),
#  ('talbanken', Node<sv-ud-train-7#29, inkomst>),
#  ('talbanken', Node<sv-ud-train-7#30, .>),
#  ('talbanken', Node<sv-ud-train-7#31, )>),
#  ('talbanken', Node<sv-ud-train-7#32, *>),
#  ('talbanken', Node<sv-ud-train-7#33, inkomst>),
#  ('talbanken', Node<sv-ud-train-7#34, av>),
#  ('talbanken', Node<sv-ud-train-7#35, jordbruksfastighet>),
#  ('talbanken', Node<sv-ud-train-7#36, ->),
#  ('talbanken', Node<sv-ud-train-7#37, om>),
#  ('talbanken', Node<sv-ud-train-7#38, den>),
#  ('talbanken', Node<sv-ud-train-7#39, skattskyldige>),
#  ('talbanken', Node<sv-ud-train-7#40, arbetat>),
#  ('talbanken', Node<sv-ud-train-7#41, i>),
#  ('talbanken', Node<sv-ud-train-7#42, jordbruket>),
#  ('talbanken', Node<sv-ud-train-7#43, i>),
#  ('talbanken', Node<sv-ud-train-7#44, ej>),
#  ('talbanken', Node<sv-ud-train-7#45, blott>),
#  ('talbanken', Node<sv-ud-train-7#46, ringa>),
#  ('talbanken', Node<sv-ud-train-7#47, omfattning>),
#  ('talbanken', Node<sv-ud-train-7#48, .>),
#  ('talbanken', Node<sv-ud-train-7#49, *>),
#  ('talbanken', Node<sv-ud-train-7#50, inkomst>),
#  ('talbanken', Node<sv-ud-train-7#51, av>),
#  ('talbanken', Node<sv-ud-train-7#52, rörelse>),
#  ('talbanken', Node<sv-ud-train-7#53, ->),
#  ('talbanken', Node<sv-ud-train-7#54, om>),
#  ('talbanken', Node<sv-ud-train-7#55, den>),
#  ('talbanken', Node<sv-ud-train-7#56, skattskyldige>),
#  ('talbanken', Node<sv-ud-train-7#57, arbetat>),
#  ('talbanken', Node<sv-ud-train-7#58, i>),
#  ('talbanken', Node<sv-ud-train-7#59, rörelsen>),
#  ('talbanken', Node<sv-ud-train-7#60, i>),
#  ('talbanken', Node<sv-ud-train-7#61, ej>),
#  ('talbanken', Node<sv-ud-train-7#62, blott>),
#  ('talbanken', Node<sv-ud-train-7#63, ringa>),
#  ('talbanken', Node<sv-ud-train-7#64, omfattning>),
#  ('talbanken', Node<sv-ud-train-7#65, .>),
#  ('talbanken', Node<sv-ud-train-8#1, Makars>),
#  ('talbanken', Node<sv-ud-train-8#2, övriga>),
#  ('talbanken', Node<sv-ud-train-8#3, inkomster>),
#  ('talbanken', Node<sv-ud-train-8#4, är>),
#  ('talbanken', Node<sv-ud-train-8#5, B-inkomster>),
#  ('talbanken', Node<sv-ud-train-8#6, och>),
#  ('talbanken', Node<sv-ud-train-8#7, skall>),
#  ('talbanken', Node<sv-ud-train-8#8, som>),
#  ('talbanken', Node<sv-ud-train-8#9, tidigare>),
#  ('talbanken', Node<sv-ud-train-8#10, sambeskattas>),
#  ('talbanken', Node<sv-ud-train-8#11, .>),
#  ('talbanken', Node<sv-ud-train-9#1, Sådana>),
#  ('talbanken', Node<sv-ud-train-9#2, B-inkomster>),
#  ('talbanken', Node<sv-ud-train-9#3, är>),
#  ('talbanken', Node<sv-ud-train-9#4, t.ex.>),
#  ('talbanken', Node<sv-ud-train-9#5, inkomst>),
#  ('talbanken', Node<sv-ud-train-9#6, av>),
#  ('talbanken', Node<sv-ud-train-9#7, kapital>),
#  ('talbanken', Node<sv-ud-train-9#8, ,>),
#  ('talbanken', Node<sv-ud-train-9#9, tillfällig>),
#  ('talbanken', Node<sv-ud-train-9#10, förvärvsverksamhet>),
#  ('talbanken', Node<sv-ud-train-9#11, ,>),
#  ('talbanken', Node<sv-ud-train-9#12, periodiskt>),
#  ('talbanken', Node<sv-ud-train-9#13, understöd>),
#  ('talbanken', Node<sv-ud-train-9#14, .>),
#  ('talbanken', Node<sv-ud-train-10#1, B-inkomster>),
#  ('talbanken', Node<sv-ud-train-10#2, som>),
#  ('talbanken', Node<sv-ud-train-10#3, för>),
#  ('talbanken', Node<sv-ud-train-10#4, makarna>),
#  ('talbanken', Node<sv-ud-train-10#5, sammanlagt>),
#  ('talbanken', Node<sv-ud-train-10#6, uppgår>),
#  ('talbanken', Node<sv-ud-train-10#7, till>),
#  ('talbanken', Node<sv-ud-train-10#8, högst>),
#  ('talbanken', Node<sv-ud-train-10#9, 2000>),
#  ('talbanken', Node<sv-ud-train-10#10, kr>),
#  ('talbanken', Node<sv-ud-train-10#11, skall>),
#  ('talbanken', Node<sv-ud-train-10#12, dock>),
#  ('talbanken', Node<sv-ud-train-10#13, betraktas>),
#  ('talbanken', Node<sv-ud-train-10#14, som>),
#  ('talbanken', Node<sv-ud-train-10#15, A-inkomst>),
#  ('talbanken', Node<sv-ud-train-10#16, och>),
#  ('talbanken', Node<sv-ud-train-10#17, alltså>),
#  ('talbanken', Node<sv-ud-train-10#18, beskattas>),
#  ('talbanken', Node<sv-ud-train-10#19, individuellt>),
#  ('talbanken', Node<sv-ud-train-10#20, .>),
#  ('talbanken', Node<sv-ud-train-11#1, Frivillig>),
#  ('talbanken', Node<sv-ud-train-11#2, särbeskattning>),
#  ('talbanken', Node<sv-ud-train-11#3, tillämpas>),
#  ('talbanken', Node<sv-ud-train-11#4, sista>),
#  ('talbanken', Node<sv-ud-train-11#5, gången>),
#  ('talbanken', Node<sv-ud-train-11#6, i>),
#  ('talbanken', Node<sv-ud-train-11#7, samband>),
#  ('talbanken', Node<sv-ud-train-11#8, med>),
#  ('talbanken', Node<sv-ud-train-11#9, 1971>),
#  ('talbanken', Node<sv-ud-train-11#10, års>),
#  ('talbanken', Node<sv-ud-train-11#11, taxering>),
#  ('talbanken', Node<sv-ud-train-11#12, .>),
#  ('talbanken', Node<sv-ud-train-12#1, Observera>),
#  ('talbanken', Node<sv-ud-train-12#2, att>),
#  ('talbanken', Node<sv-ud-train-12#3, ansökan>),
#  ('talbanken', Node<sv-ud-train-12#4, härom>),
#  ('talbanken', Node<sv-ud-train-12#5, skall>),
#  ('talbanken', Node<sv-ud-train-12#6, göras>),
#  ('talbanken', Node<sv-ud-train-12#7, senast>),
#  ('talbanken', Node<sv-ud-train-12#8, den>),
#  ('talbanken', Node<sv-ud-train-12#9, 1>),
#  ('talbanken', Node<sv-ud-train-12#10, juli>),
#  ('talbanken', Node<sv-ud-train-12#11, 1971>),
#  ('talbanken', Node<sv-ud-train-12#12, .>),
#  ('talbanken', Node<sv-ud-train-13#1, Kommunalskatteavdraget>),
#  ('talbanken', Node<sv-ud-train-13#2, slopas>),
#  ('talbanken', Node<sv-ud-train-14#1, För>),
#  ('talbanken', Node<sv-ud-train-14#2, fysiska>),
#  ('talbanken', Node<sv-ud-train-14#3, personer>),
#  ('talbanken', Node<sv-ud-train-14#4, ,>),
#  ('talbanken', Node<sv-ud-train-14#5, dödsbon>),
#  ('talbanken', Node<sv-ud-train-14#6, och>),
#  ('talbanken', Node<sv-ud-train-14#7, familjestiftelser>),
#  ('talbanken', Node<sv-ud-train-14#8, slopas>),
#  ('talbanken', Node<sv-ud-train-14#9, rätten>),
#  ('talbanken', Node<sv-ud-train-14#10, att>),
#  ('talbanken', Node<sv-ud-train-14#11, göra>),
#  ('talbanken', Node<sv-ud-train-14#12, avdrag>),
#  ('talbanken', Node<sv-ud-train-14#13, för>),
#  ('talbanken', Node<sv-ud-train-14#14, kommunalskatten>),
#  ('talbanken', Node<sv-ud-train-14#15, fr.o.m.>),
#  ('talbanken', Node<sv-ud-train-14#16, den>),
#  ('talbanken', Node<sv-ud-train-14#17, självdeklaration>),
#  ('talbanken', Node<sv-ud-train-14#18, som>),
#  ('talbanken', Node<sv-ud-train-14#19, skall>),
#  ('talbanken', Node<sv-ud-train-14#20, avlämnas>),
#  ('talbanken', Node<sv-ud-train-14#21, 1972>),
#  ('talbanken', Node<sv-ud-train-14#22, .>),
#  ('talbanken', Node<sv-ud-train-15#1, I>),
#  ('talbanken', Node<sv-ud-train-15#2, självdeklarationen>),
#  ('talbanken', Node<sv-ud-train-15#3, 1971>),
#  ('talbanken', Node<sv-ud-train-15#4, ->),
#  ('talbanken', Node<sv-ud-train-15#5, som>),
#  ('talbanken', Node<sv-ud-train-15#6, alltså>),
#  ('talbanken', Node<sv-ud-train-15#7, avser>),
#  ('talbanken', Node<sv-ud-train-15#8, 1970>),
#  ('talbanken', Node<sv-ud-train-15#9, års>),
#  ('talbanken', Node<sv-ud-train-15#10, inkomster>),
#  ('talbanken', Node<sv-ud-train-15#11, ->),
#  ('talbanken', Node<sv-ud-train-15#12, får>),
#  ('talbanken', Node<sv-ud-train-15#13, avdrag>),
#  ('talbanken', Node<sv-ud-train-15#14, göras>),
#  ('talbanken', Node<sv-ud-train-15#15, som>),
#  ('talbanken', Node<sv-ud-train-15#16, tidigare>),
#  ('talbanken', Node<sv-ud-train-15#17, .>),
#  ('talbanken', Node<sv-ud-train-16#1, Förvärvsavdragen>),
#  ('talbanken', Node<sv-ud-train-16#2, ändras>),
#  ('talbanken', Node<sv-ud-train-17#1, Förvärvsavdrag>),
#  ('talbanken', Node<sv-ud-train-17#2, kan>),
#  ('talbanken', Node<sv-ud-train-17#3, medges>),
#  ('talbanken', Node<sv-ud-train-17#4, från>),
#  ('talbanken', Node<sv-ud-train-17#5, A-inkomst>),
#  ('talbanken', Node<sv-ud-train-17#6, ,>),
#  ('talbanken', Node<sv-ud-train-17#7, om>),
#  ('talbanken', Node<sv-ud-train-17#8, det>),
#  ('talbanken', Node<sv-ud-train-17#9, finns>),
#  ('talbanken', Node<sv-ud-train-17#10, hemmavarande>),
#  ('talbanken', Node<sv-ud-train-17#11, barn>),
#  ('talbanken', Node<sv-ud-train-17#12, under>),
#  ('talbanken', Node<sv-ud-train-17#13, 16>),
#  ('talbanken', Node<sv-ud-train-17#14, år>),
#  ('talbanken', Node<sv-ud-train-17#15, .>),
#  ('talbanken', Node<sv-ud-train-18#1, Sådant>),
#  ('talbanken', Node<sv-ud-train-18#2, avdrag>),
#  ('talbanken', Node<sv-ud-train-18#3, medges>),
#  ('talbanken', Node<sv-ud-train-18#4, på>),
#  ('talbanken', Node<sv-ud-train-18#5, sätt>),
#  ('talbanken', Node<sv-ud-train-18#6, framgår>),
#  ('talbanken', Node<sv-ud-train-18#7, av>),
#  ('talbanken', Node<sv-ud-train-18#8, nedanstående>),
#  ('talbanken', Node<sv-ud-train-18#9, tablå>),
#  ('talbanken', Node<sv-ud-train-18#10, .>),
#  ('talbanken', Node<sv-ud-train-19#1, Barns>),
#  ('talbanken', Node<sv-ud-train-19#2, ålder>),
#  ('talbanken', Node<sv-ud-train-19#3, räknas>),
#  ('talbanken', Node<sv-ud-train-19#4, efter>),
#  ('talbanken', Node<sv-ud-train-19#5, förhållandet>),
#  ('talbanken', Node<sv-ud-train-19#6, den>),
#  ('talbanken', Node<sv-ud-train-19#7, 1>),
#  ('talbanken', Node<sv-ud-train-19#8, november>),
#  ('talbanken', Node<sv-ud-train-19#9, under>),
#  ('talbanken', Node<sv-ud-train-19#10, inkomståret>),
#  ('talbanken', Node<sv-ud-train-19#11, .>),
#  ('talbanken', Node<sv-ud-train-20#1, När>),
#  ('talbanken', Node<sv-ud-train-20#2, det>),
#  ('talbanken', Node<sv-ud-train-20#3, gäller>),
#  ('talbanken', Node<sv-ud-train-20#4, inkomståret>),
#  ('talbanken', Node<sv-ud-train-20#5, 1971>),
#  ('talbanken', Node<sv-ud-train-20#6, (>),
#  ('talbanken', Node<sv-ud-train-20#7, taxeringsåret>),
#  ('talbanken', Node<sv-ud-train-20#8, 1972>),
#  ('talbanken', Node<sv-ud-train-20#9, )>),
#  ('talbanken', Node<sv-ud-train-20#10, skall>),
#  ('talbanken', Node<sv-ud-train-20#11, barnet>),
#  ('talbanken', Node<sv-ud-train-20#12, alltså>),
#  ('talbanken', Node<sv-ud-train-20#13, vara>),
#  ('talbanken', Node<sv-ud-train-20#14, fött>),
#  ('talbanken', Node<sv-ud-train-20#15, efter>),
#  ('talbanken', Node<sv-ud-train-20#16, den>),
#  ('talbanken', Node<sv-ud-train-20#17, 1>),
#  ('talbanken', Node<sv-ud-train-20#18, november>),
#  ('talbanken', Node<sv-ud-train-20#19, 1955>),
#  ('talbanken', Node<sv-ud-train-20#20, .>),
#  ('talbanken', Node<sv-ud-train-21#1, Med>),
#  ('talbanken', Node<sv-ud-train-21#2, makar>),
#  ('talbanken', Node<sv-ud-train-21#3, likställs>),
#  ('talbanken', Node<sv-ud-train-21#4, de>),
#  ('talbanken', Node<sv-ud-train-21#5, som>),
#  ('talbanken', Node<sv-ud-train-21#6, utan>),
#  ('talbanken', Node<sv-ud-train-21#7, att>),
#  ('talbanken', Node<sv-ud-train-21#8, vara>),
#  ('talbanken', Node<sv-ud-train-21#9, gifta>),
#  ('talbanken', Node<sv-ud-train-21#10, lever>),
#  ('talbanken', Node<sv-ud-train-21#11, tillsammans>),
#  ('talbanken', Node<sv-ud-train-21#12, om>),
#  ('talbanken', Node<sv-ud-train-21#13, de>),
#  ('talbanken', Node<sv-ud-train-21#14, tidigare>),
#  ('talbanken', Node<sv-ud-train-21#15, varit>),
#  ('talbanken', Node<sv-ud-train-21#16, gifta>),
#  ('talbanken', Node<sv-ud-train-21#17, med>),
#  ('talbanken', Node<sv-ud-train-21#18, varandra>),
#  ('talbanken', Node<sv-ud-train-21#19, eller>),
#  ('talbanken', Node<sv-ud-train-21#20, har>),
#  ('talbanken', Node<sv-ud-train-21#21, eller>),
#  ('talbanken', Node<sv-ud-train-21#22, har>),
#  ('talbanken', Node<sv-ud-train-21#23, haft>),
#  ('talbanken', Node<sv-ud-train-21#24, barn>),
#  ('talbanken', Node<sv-ud-train-21#25, gemensamt>),
#  ('talbanken', Node<sv-ud-train-21#26, .>),
#  ('talbanken', Node<sv-ud-train-22#1, Höjt>),
#  ('talbanken', Node<sv-ud-train-22#2, avdrag>),
#  ('talbanken', Node<sv-ud-train-22#3, för>),
#  ('talbanken', Node<sv-ud-train-22#4, underhållsbidrag>),
#  ('talbanken', Node<sv-ud-train-22#5, till>),
#  ('talbanken', Node<sv-ud-train-22#6, icke>),
#  ('talbanken', Node<sv-ud-train-22#7, hemmavarande>),
#  ('talbanken', Node<sv-ud-train-22#8, barn>),
#  ('talbanken', Node<sv-ud-train-23#1, Avdrag>),
#  ('talbanken', Node<sv-ud-train-23#2, för>),
#  ('talbanken', Node<sv-ud-train-23#3, utgivet>),
#  ('talbanken', Node<sv-ud-train-23#4, underhållsbidrag>),
#  ('talbanken', Node<sv-ud-train-23#5, till>),
#  ('talbanken', Node<sv-ud-train-23#6, icke>),
#  ('talbanken', Node<sv-ud-train-23#7, hemmavarande>),
#  ('talbanken', Node<sv-ud-train-23#8, barn>),
#  ('talbanken', Node<sv-ud-train-23#9, höjs>),
#  ('talbanken', Node<sv-ud-train-23#10, från>),
#  ('talbanken', Node<sv-ud-train-23#11, 1000>),
#  ('talbanken', Node<sv-ud-train-23#12, kr>),
#  ('talbanken', Node<sv-ud-train-23#13, till>),
#  ('talbanken', Node<sv-ud-train-23#14, 1500>),
#  ('talbanken', Node<sv-ud-train-23#15, kr>),
#  ('talbanken', Node<sv-ud-train-23#16, per>),
#  ('talbanken', Node<sv-ud-train-23#17, barn>),
#  ('talbanken', Node<sv-ud-train-23#18, och>),
#  ('talbanken', Node<sv-ud-train-23#19, år>),
#  ('talbanken', Node<sv-ud-train-23#20, .>),
#  ('talbanken', Node<sv-ud-train-24#1, Dessutom>),
#  ('talbanken', Node<sv-ud-train-24#2, höjs>),
#  ('talbanken', Node<sv-ud-train-24#3, åldergränsen>),
#  ('talbanken', Node<sv-ud-train-24#4, till>),
#  ('talbanken', Node<sv-ud-train-24#5, 18>),
#  ('talbanken', Node<sv-ud-train-24#6, år>),
#  ('talbanken', Node<sv-ud-train-24#7, .>),
#  ('talbanken', Node<sv-ud-train-25#1, När>),
#  ('talbanken', Node<sv-ud-train-25#2, det>),
#  ('talbanken', Node<sv-ud-train-25#3, gäller>),
#  ('talbanken', Node<sv-ud-train-25#4, 1972>),
#  ('talbanken', Node<sv-ud-train-25#5, års>),
#  ('talbanken', Node<sv-ud-train-25#6, taxering>),
#  ('talbanken', Node<sv-ud-train-25#7, skall>),
#  ('talbanken', Node<sv-ud-train-25#8, barnet>),
#  ('talbanken', Node<sv-ud-train-25#9, vara>),
#  ('talbanken', Node<sv-ud-train-25#10, fött>),
#  ('talbanken', Node<sv-ud-train-25#11, efter>),
#  ('talbanken', Node<sv-ud-train-25#12, den>),
#  ('talbanken', Node<sv-ud-train-25#13, 1>),
#  ('talbanken', Node<sv-ud-train-25#14, november>),
#  ('talbanken', Node<sv-ud-train-25#15, 1953>),
#  ('talbanken', Node<sv-ud-train-25#16, .>),
#  ('talbanken', Node<sv-ud-train-26#1, Kravet>),
#  ('talbanken', Node<sv-ud-train-26#2, på>),
#  ('talbanken', Node<sv-ud-train-26#3, bevisning>),
#  ('talbanken', Node<sv-ud-train-26#4, har>),
#  ('talbanken', Node<sv-ud-train-26#5, mildrats>),
#  ('talbanken', Node<sv-ud-train-26#6, .>),
#  ('talbanken', Node<sv-ud-train-27#1, Avdraget>),
#  ('talbanken', Node<sv-ud-train-27#2, måste>),
#  ('talbanken', Node<sv-ud-train-27#3, inte>),
#  ('talbanken', Node<sv-ud-train-27#4, längre>),
#  ('talbanken', Node<sv-ud-train-27#5, styrkas>),
#  ('talbanken', Node<sv-ud-train-27#6, med>),
#  ('talbanken', Node<sv-ud-train-27#7, intyg>),
#  ('talbanken', Node<sv-ud-train-27#8, från>),
#  ('talbanken', Node<sv-ud-train-27#9, barnavårdsnämnd>),
#  ('talbanken', Node<sv-ud-train-27#10, ,>),
#  ('talbanken', Node<sv-ud-train-27#11, barnavårdsman>),
#  ('talbanken', Node<sv-ud-train-27#12, eller>),
#  ('talbanken', Node<sv-ud-train-27#13, kommunal>),
#  ('talbanken', Node<sv-ud-train-27#14, förtroendeman>),
#  ('talbanken', Node<sv-ud-train-27#15, .>),
#  ('talbanken', Node<sv-ud-train-28#1, Det>),
#  ('talbanken', Node<sv-ud-train-28#2, räcker>),
#  ('talbanken', Node<sv-ud-train-28#3, med>),
#  ('talbanken', Node<sv-ud-train-28#4, att>),
#  ('talbanken', Node<sv-ud-train-28#5, intyg>),
#  ('talbanken', Node<sv-ud-train-28#6, eller>),
#  ('talbanken', Node<sv-ud-train-28#7, annat>),
#  ('talbanken', Node<sv-ud-train-28#8, skriftligt>),
#  ('talbanken', Node<sv-ud-train-28#9, bevis>),
#  ('talbanken', Node<sv-ud-train-28#10, bifogas>),
#  ('talbanken', Node<sv-ud-train-28#11, deklarationen>),
#  ('talbanken', Node<sv-ud-train-28#12, .>),
#  ('talbanken', Node<sv-ud-train-29#1, Som>),
#  ('talbanken', Node<sv-ud-train-29#2, bevis>),
#  ('talbanken', Node<sv-ud-train-29#3, torde>),
#  ('talbanken', Node<sv-ud-train-29#4, godtas>),
#  ('talbanken', Node<sv-ud-train-29#5, dom>),
#  ('talbanken', Node<sv-ud-train-29#6, eller>),
#  ('talbanken', Node<sv-ud-train-29#7, avtal>),
#  ('talbanken', Node<sv-ud-train-29#8, om>),
#  ('talbanken', Node<sv-ud-train-29#9, underhållsskyldighet>),
#  ('talbanken', Node<sv-ud-train-29#10, jämte>),
#  ('talbanken', Node<sv-ud-train-29#11, kvitto>),
#  ('talbanken', Node<sv-ud-train-29#12, på>),
#  ('talbanken', Node<sv-ud-train-29#13, betalt>),
#  ('talbanken', Node<sv-ud-train-29#14, belopp>),
#  ('talbanken', Node<sv-ud-train-29#15, eller>),
#  ('talbanken', Node<sv-ud-train-29#16, intyg>),
#  ('talbanken', Node<sv-ud-train-29#17, från>),
#  ('talbanken', Node<sv-ud-train-29#18, trovärdig>),
#  ('talbanken', Node<sv-ud-train-29#19, person>),
#  ('talbanken', Node<sv-ud-train-29#20, .>),
#  ('talbanken', Node<sv-ud-train-30#1, Ortsavdraget>),
#  ('talbanken', Node<sv-ud-train-30#2, ersätts>),
#  ('talbanken', Node<sv-ud-train-30#3, med>),
#  ('talbanken', Node<sv-ud-train-30#4, grundavdrag>),
#  ('talbanken', Node<sv-ud-train-30#5, .>),
#  ('talbanken', Node<sv-ud-train-31#1, Det>),
#  ('talbanken', Node<sv-ud-train-31#2, nya>),
#  ('talbanken', Node<sv-ud-train-31#3, grundavdraget>),
#  ('talbanken', Node<sv-ud-train-31#4, ->),
#  ('talbanken', Node<sv-ud-train-31#5, som>),
#  ('talbanken', Node<sv-ud-train-31#6, ersätter>),
#  ('talbanken', Node<sv-ud-train-31#7, tidigare>),
#  ('talbanken', Node<sv-ud-train-31#8, ortsavdrag>),
#  ('talbanken', Node<sv-ud-train-31#9, ->),
#  ('talbanken', Node<sv-ud-train-31#10, uppgår>),
#  ('talbanken', Node<sv-ud-train-31#11, till>),
#  ('talbanken', Node<sv-ud-train-31#12, 4500>),
#  ('talbanken', Node<sv-ud-train-31#13, kr>),
#  ('talbanken', Node<sv-ud-train-31#14, för>),
#  ('talbanken', Node<sv-ud-train-31#15, varje>),
#  ('talbanken', Node<sv-ud-train-31#16, skattskyldig>),
#  ('talbanken', Node<sv-ud-train-31#17, med>),
#  ('talbanken', Node<sv-ud-train-31#18, en>),
#  ('talbanken', Node<sv-ud-train-31#19, till>),
#  ('talbanken', Node<sv-ud-train-31#20, statlig>),
#  ('talbanken', Node<sv-ud-train-31#21, inkomstskatt>),
#  ('talbanken', Node<sv-ud-train-31#22, taxerad>),
#  ('talbanken', Node<sv-ud-train-31#23, inkomst>),
#  ('talbanken', Node<sv-ud-train-31#24, av>),
#  ('talbanken', Node<sv-ud-train-31#25, högst>),
#  ('talbanken', Node<sv-ud-train-31#26, 30000>),
#  ('talbanken', Node<sv-ud-train-31#27, kr>),
#  ('talbanken', Node<sv-ud-train-31#28, .>),
#  ('talbanken', Node<sv-ud-train-32#1, Vid>),
#  ('talbanken', Node<sv-ud-train-32#2, högre>),
#  ('talbanken', Node<sv-ud-train-32#3, taxerad>),
#  ('talbanken', Node<sv-ud-train-32#4, inkomst>),
#  ('talbanken', Node<sv-ud-train-32#5, sjunker>),
#  ('talbanken', Node<sv-ud-train-32#6, avdraget>),
#  ('talbanken', Node<sv-ud-train-32#7, med>),
#  ('talbanken', Node<sv-ud-train-32#8, en>),
#  ('talbanken', Node<sv-ud-train-32#9, femtedel>),
#  ('talbanken', Node<sv-ud-train-32#10, av>),
#  ('talbanken', Node<sv-ud-train-32#11, det>),
#  ('talbanken', Node<sv-ud-train-32#12, belopp>),
#  ('talbanken', Node<sv-ud-train-32#13, som>),
#  ('talbanken', Node<sv-ud-train-32#14, överstiger>),
#  ('talbanken', Node<sv-ud-train-32#15, 30000>),
#  ('talbanken', Node<sv-ud-train-32#16, kronor>),
#  ('talbanken', Node<sv-ud-train-32#17, .>),
#  ('talbanken', Node<sv-ud-train-33#1, Grundavdraget>),
#  ('talbanken', Node<sv-ud-train-33#2, upphör>),
#  ('talbanken', Node<sv-ud-train-33#3, alltså>),
#  ('talbanken', Node<sv-ud-train-33#4, vid>),
#  ('talbanken', Node<sv-ud-train-33#5, en>),
#  ('talbanken', Node<sv-ud-train-33#6, taxerad>),
#  ('talbanken', Node<sv-ud-train-33#7, inkomst>),
#  ('talbanken', Node<sv-ud-train-33#8, på>),
#  ('talbanken', Node<sv-ud-train-33#9, 52500>),
#  ('talbanken', Node<sv-ud-train-33#10, kr>),
#  ('talbanken', Node<sv-ud-train-33#11, .>),
#  ('talbanken', Node<sv-ud-train-34#1, Exempel>),
#  ('talbanken', Node<sv-ud-train-34#2, :>),
#  ('talbanken', Node<sv-ud-train-35#1, Statligt>),
#  ('talbanken', Node<sv-ud-train-35#2, taxerad>),
#  ('talbanken', Node<sv-ud-train-35#3, inkomst>),
#  ('talbanken', Node<sv-ud-train-35#4, uppgår>),
#  ('talbanken', Node<sv-ud-train-35#5, till>),
#  ('talbanken', Node<sv-ud-train-35#6, 40000>),
#  ('talbanken', Node<sv-ud-train-35#7, kr>),
#  ('talbanken', Node<sv-ud-train-35#8, .>),
#  ('talbanken', Node<sv-ud-train-36#1, Grundavdraget>),
#  ('talbanken', Node<sv-ud-train-36#2, blir>),
#  ('talbanken', Node<sv-ud-train-36#3, 2500>),
#  ('talbanken', Node<sv-ud-train-36#4, kr>),
#  ('talbanken', Node<sv-ud-train-36#5, (>),
#  ('talbanken', Node<sv-ud-train-36#6, =>),
#  ('talbanken', Node<sv-ud-train-36#7, 4500>),
#  ('talbanken', Node<sv-ud-train-36#8, minskat>),
#  ('talbanken', Node<sv-ud-train-36#9, med>),
#  ('talbanken', Node<sv-ud-train-36#10, 1/5>),
#  ('talbanken', Node<sv-ud-train-36#11, av>),
#  ('talbanken', Node<sv-ud-train-36#12, 10000>),
#  ('talbanken', Node<sv-ud-train-36#13, kr>),
#  ('talbanken', Node<sv-ud-train-36#14, )>),
#  ('talbanken', Node<sv-ud-train-36#15, .>),
#  ('talbanken', Node<sv-ud-train-37#1, Grundavdraget>),
#  ('talbanken', Node<sv-ud-train-37#2, uppgår>),
#  ('talbanken', Node<sv-ud-train-37#3, till>),
#  ('talbanken', Node<sv-ud-train-37#4, samma>),
#  ('talbanken', Node<sv-ud-train-37#5, belopp>),
#  ('talbanken', Node<sv-ud-train-37#6, vid>),
#  ('talbanken', Node<sv-ud-train-37#7, statlig>),
#  ('talbanken', Node<sv-ud-train-37#8, och>),
#  ('talbanken', Node<sv-ud-train-37#9, kommunal>),
#  ('talbanken', Node<sv-ud-train-37#10, taxering>),
#  ('talbanken', Node<sv-ud-train-37#11, och>),
#  ('talbanken', Node<sv-ud-train-37#12, beräknas>),
#  ('talbanken', Node<sv-ud-train-37#13, med>),
#  ('talbanken', Node<sv-ud-train-37#14, ledning>),
#  ('talbanken', Node<sv-ud-train-37#15, av>),
#  ('talbanken', Node<sv-ud-train-37#16, den>),
#  ('talbanken', Node<sv-ud-train-37#17, till>),
#  ('talbanken', Node<sv-ud-train-37#18, statlig>),
#  ('talbanken', Node<sv-ud-train-37#19, inkomstskatt>),
#  ('talbanken', Node<sv-ud-train-37#20, taxerade>),
#  ('talbanken', Node<sv-ud-train-37#21, inkomsten>),
#  ('talbanken', Node<sv-ud-train-37#22, .>),
#  ('talbanken', Node<sv-ud-train-38#1, Kommunalt>),
#  ('talbanken', Node<sv-ud-train-38#2, grundavdrag>),
#  ('talbanken', Node<sv-ud-train-38#3, kan>),
#  ('talbanken', Node<sv-ud-train-38#4, avräknas>),
#  ('talbanken', Node<sv-ud-train-38#5, även>),
#  ('talbanken', Node<sv-ud-train-38#6, från>),
#  ('talbanken', Node<sv-ud-train-38#7, inkomst>),
#  ('talbanken', Node<sv-ud-train-38#8, i>),
#  ('talbanken', Node<sv-ud-train-38#9, annan>),
#  ('talbanken', Node<sv-ud-train-38#10, kommun>),
#  ('talbanken', Node<sv-ud-train-38#11, än>),
#  ('talbanken', Node<sv-ud-train-38#12, hemortskommunen>),
#  ('talbanken', Node<sv-ud-train-38#13, .>),
#  ('talbanken', Node<sv-ud-train-39#1, För>),
#  ('talbanken', Node<sv-ud-train-39#2, ena>),
#  ('talbanken', Node<sv-ud-train-39#3, maken>),
#  ('talbanken', Node<sv-ud-train-39#4, outnyttjat>),
#  ('talbanken', Node<sv-ud-train-39#5, grundavdrag>),
#  ('talbanken', Node<sv-ud-train-39#6, eller>),
#  ('talbanken', Node<sv-ud-train-39#7, del>),
#  ('talbanken', Node<sv-ud-train-39#8, därav>),
#  ('talbanken', Node<sv-ud-train-39#9, kan>),
#  ('talbanken', Node<sv-ud-train-39#10, inte>),
#  ('talbanken', Node<sv-ud-train-39#11, överföras>),
#  ('talbanken', Node<sv-ud-train-39#12, till>),
#  ('talbanken', Node<sv-ud-train-39#13, den>),
#  ('talbanken', Node<sv-ud-train-39#14, andra>),
#  ('talbanken', Node<sv-ud-train-39#15, maken>),
#  ('talbanken', Node<sv-ud-train-39#16, .>),
#  ('talbanken', Node<sv-ud-train-40#1, I>),
#  ('talbanken', Node<sv-ud-train-40#2, sådant>),
#  ('talbanken', Node<sv-ud-train-40#3, fall>),
#  ('talbanken', Node<sv-ud-train-40#4, har>),
#  ('talbanken', Node<sv-ud-train-40#5, dock>),
#  ('talbanken', Node<sv-ud-train-40#6, den>),
#  ('talbanken', Node<sv-ud-train-40#7, andra>),
#  ('talbanken', Node<sv-ud-train-40#8, maken>),
#  ('talbanken', Node<sv-ud-train-40#9, rätt>),
#  ('talbanken', Node<sv-ud-train-40#10, till>),
#  ('talbanken', Node<sv-ud-train-40#11, skattereduktion>),
#  ('talbanken', Node<sv-ud-train-40#12, (>),
#  ('talbanken', Node<sv-ud-train-40#13, se>),
#  ('talbanken', Node<sv-ud-train-40#14, nedan>),
#  ('talbanken', Node<sv-ud-train-40#15, )>),
#  ('talbanken', Node<sv-ud-train-40#16, .>),
#  ('talbanken', Node<sv-ud-train-41#1, Särskilda>),
#  ('talbanken', Node<sv-ud-train-41#2, regler>),
#  ('talbanken', Node<sv-ud-train-41#3, gäller>),
#  ('talbanken', Node<sv-ud-train-41#4, för>),
#  ('talbanken', Node<sv-ud-train-41#5, *>),
#  ('talbanken', Node<sv-ud-train-41#6, skattskyldig>),
#  ('talbanken', Node<sv-ud-train-41#7, som>),
#  ('talbanken', Node<sv-ud-train-41#8, varit>),
#  ('talbanken', Node<sv-ud-train-41#9, bosatt>),
#  ('talbanken', Node<sv-ud-train-41#10, här>),
#  ('talbanken', Node<sv-ud-train-41#11, i>),
#  ('talbanken', Node<sv-ud-train-41#12, riket>),
#  ('talbanken', Node<sv-ud-train-41#13, under>),
#  ('talbanken', Node<sv-ud-train-41#14, en>),
#  ('talbanken', Node<sv-ud-train-41#15, mindre>),
#  ('talbanken', Node<sv-ud-train-41#16, del>),
#  ('talbanken', Node<sv-ud-train-41#17, av>),
#  ('talbanken', Node<sv-ud-train-41#18, beskattningsåret>),
#  ('talbanken', Node<sv-ud-train-41#19, *>),
#  ('talbanken', Node<sv-ud-train-41#20, skattskyldig>),
#  ('talbanken', Node<sv-ud-train-41#21, som>),
#  ('talbanken', Node<sv-ud-train-41#22, haft>),
#  ('talbanken', Node<sv-ud-train-41#23, inkomst>),
#  ('talbanken', Node<sv-ud-train-41#24, som>),
#  ('talbanken', Node<sv-ud-train-41#25, beskattas>),
#  ('talbanken', Node<sv-ud-train-41#26, enligt>),
#  ('talbanken', Node<sv-ud-train-41#27, förordningen>),
#  ('talbanken', Node<sv-ud-train-41#28, om>),
#  ('talbanken', Node<sv-ud-train-41#29, sjömansskatt>),
#  ('talbanken', Node<sv-ud-train-41#30, .>),
#  ('talbanken', Node<sv-ud-train-42#1, Gränsen>),
#  ('talbanken', Node<sv-ud-train-42#2, för>),
#  ('talbanken', Node<sv-ud-train-42#3, den>),
#  ('talbanken', Node<sv-ud-train-42#4, årsinkomst>),
#  ('talbanken', Node<sv-ud-train-42#5, feriearbetande>),
#  ('talbanken', Node<sv-ud-train-42#6, ungdom>),
#  ('talbanken', Node<sv-ud-train-42#7, m.fl>),
#  ('talbanken', Node<sv-ud-train-42#8, får>),
#  ('talbanken', Node<sv-ud-train-42#9, ha>),
#  ('talbanken', Node<sv-ud-train-42#10, av>),
#  ('talbanken', Node<sv-ud-train-42#11, tillfällig>),
#  ('talbanken', Node<sv-ud-train-42#12, anställning>),
#  ('talbanken', Node<sv-ud-train-42#13, utan>),
#  ('talbanken', Node<sv-ud-train-42#14, att>),
#  ('talbanken', Node<sv-ud-train-42#15, betala>),
#  ('talbanken', Node<sv-ud-train-42#16, preliminärskatt>),
#  ('talbanken', Node<sv-ud-train-42#17, höjs>),
#  ('talbanken', Node<sv-ud-train-42#18, genom>),
#  ('talbanken', Node<sv-ud-train-42#19, de>),
#  ('talbanken', Node<sv-ud-train-42#20, nya>),
#  ('talbanken', Node<sv-ud-train-42#21, bestämmelserna>),
#  ('talbanken', Node<sv-ud-train-42#22, till>),
#  ('talbanken', Node<sv-ud-train-42#23, 4700>),
#  ('talbanken', Node<sv-ud-train-42#24, kr>),
#  ('talbanken', Node<sv-ud-train-42#25, .>),
#  ('talbanken', Node<sv-ud-train-43#1, Skattelättnad>),
#  ('talbanken', Node<sv-ud-train-43#2, för>),
#  ('talbanken', Node<sv-ud-train-43#3, folkpensionärer>),
#  ('talbanken', Node<sv-ud-train-44#1, I>),
#  ('talbanken', Node<sv-ud-train-44#2, det>),
#  ('talbanken', Node<sv-ud-train-44#3, nya>),
#  ('talbanken', Node<sv-ud-train-44#4, skattesystemet>),
#  ('talbanken', Node<sv-ud-train-44#5, bibehålls>),
#  ('talbanken', Node<sv-ud-train-44#6, den>),
#  ('talbanken', Node<sv-ud-train-44#7, gamla>),
#  ('talbanken', Node<sv-ud-train-44#8, regeln>),
#  ('talbanken', Node<sv-ud-train-44#9, att>),
#  ('talbanken', Node<sv-ud-train-44#10, skattskyldig>),
#  ('talbanken', Node<sv-ud-train-44#11, som>),
#  ('talbanken', Node<sv-ud-train-44#12, bara>),
#  ('talbanken', Node<sv-ud-train-44#13, har>),
#  ('talbanken', Node<sv-ud-train-44#14, folkpension>),
#  ('talbanken', Node<sv-ud-train-44#15, ,>),
#  ('talbanken', Node<sv-ud-train-44#16, inte>),
#  ('talbanken', Node<sv-ud-train-44#17, påförs>),
#  ('talbanken', Node<sv-ud-train-44#18, någon>),
#  ('talbanken', Node<sv-ud-train-44#19, skatt>),
#  ('talbanken', Node<sv-ud-train-44#20, .>),
#  ('talbanken', Node<sv-ud-train-45#1, En>),
#  ('talbanken', Node<sv-ud-train-45#2, nyhet>),
#  ('talbanken', Node<sv-ud-train-45#3, är>),
#  ('talbanken', Node<sv-ud-train-45#4, att>),
#  ('talbanken', Node<sv-ud-train-45#5, det>),
#  ('talbanken', Node<sv-ud-train-45#6, kommunala>),
#  ('talbanken', Node<sv-ud-train-45#7, bostadstillägget>),
#  ('talbanken', Node<sv-ud-train-45#8, blir>),
#  ('talbanken', Node<sv-ud-train-45#9, skattefritt>),
#  ('talbanken', Node<sv-ud-train-45#10, oavsett>),
#  ('talbanken', Node<sv-ud-train-45#11, hur>),
#  ('talbanken', Node<sv-ud-train-45#12, hög>),
#  ('talbanken', Node<sv-ud-train-45#13, inkomst>),
#  ('talbanken', Node<sv-ud-train-45#14, folkpensionären>),
#  ('talbanken', Node<sv-ud-train-45#15, har>),
#  ('talbanken', Node<sv-ud-train-45#16, .>),
#  ('talbanken', Node<sv-ud-train-46#1, Dessutom>),
#  ('talbanken', Node<sv-ud-train-46#2, kommer>),
#  ('talbanken', Node<sv-ud-train-46#3, en>),
#  ('talbanken', Node<sv-ud-train-46#4, ensamstående>),
#  ('talbanken', Node<sv-ud-train-46#5, folkpensionär>),
#  ('talbanken', Node<sv-ud-train-46#6, att>),
#  ('talbanken', Node<sv-ud-train-46#7, kunna>),
#  ('talbanken', Node<sv-ud-train-46#8, ha>),
#  ('talbanken', Node<sv-ud-train-46#9, en>),
#  ('talbanken', Node<sv-ud-train-46#10, inkomst>),
#  ('talbanken', Node<sv-ud-train-46#11, om>),
#  ('talbanken', Node<sv-ud-train-46#12, 1500>),
#  ('talbanken', Node<sv-ud-train-46#13, kr>),
#  ('talbanken', Node<sv-ud-train-46#14, vid>),
#  ('talbanken', Node<sv-ud-train-46#15, sidan>),
#  ('talbanken', Node<sv-ud-train-46#16, av>),
#  ('talbanken', Node<sv-ud-train-46#17, folkpensionen>),
#  ('talbanken', Node<sv-ud-train-46#18, och>),
#  ('talbanken', Node<sv-ud-train-46#19, ändock>),
#  ('talbanken', Node<sv-ud-train-46#20, bli>),
#  ('talbanken', Node<sv-ud-train-46#21, skattefri>),
#  ('talbanken', Node<sv-ud-train-46#22, .>),
#  ('talbanken', Node<sv-ud-train-47#1, Gifta>),
#  ('talbanken', Node<sv-ud-train-47#2, pensionärer>),
#  ('talbanken', Node<sv-ud-train-47#3, blir>),
#  ('talbanken', Node<sv-ud-train-47#4, skattefria>),
#  ('talbanken', Node<sv-ud-train-47#5, om>),
#  ('talbanken', Node<sv-ud-train-47#6, sidoinkomsten>),
#  ('talbanken', Node<sv-ud-train-47#7, uppgår>),
#  ('talbanken', Node<sv-ud-train-47#8, till>),
#  ('talbanken', Node<sv-ud-train-47#9, högst>),
#  ('talbanken', Node<sv-ud-train-47#10, 2000>),
#  ('talbanken', Node<sv-ud-train-47#11, kr>),
#  ('talbanken', Node<sv-ud-train-47#12, för>),
#  ('talbanken', Node<sv-ud-train-47#13, makarna>),
#  ('talbanken', Node<sv-ud-train-47#14, tillsammans>),
#  ('talbanken', Node<sv-ud-train-47#15, .>),
#  ('talbanken', Node<sv-ud-train-48#1, Tekniskt>),
#  ('talbanken', Node<sv-ud-train-48#2, ordnas>),
#  ('talbanken', Node<sv-ud-train-48#3, detta>),
#  ('talbanken', Node<sv-ud-train-48#4, genom>),
#  ('talbanken', Node<sv-ud-train-48#5, ett>),
#  ('talbanken', Node<sv-ud-train-48#6, extra>),
#  ('talbanken', Node<sv-ud-train-48#7, avdrag>),
#  ('talbanken', Node<sv-ud-train-48#8, utöver>),
#  ('talbanken', Node<sv-ud-train-48#9, grundavdraget>),
#  ('talbanken', Node<sv-ud-train-48#10, .>),
#  ('talbanken', Node<sv-ud-train-49#1, För>),
#  ('talbanken', Node<sv-ud-train-49#2, att>),
#  ('talbanken', Node<sv-ud-train-49#3, belysa>),
#  ('talbanken', Node<sv-ud-train-49#4, verkningarna>),
#  ('talbanken', Node<sv-ud-train-49#5, för>),
#  ('talbanken', Node<sv-ud-train-49#6, folkpensionärerna>),
#  ('talbanken', Node<sv-ud-train-49#7, av>),
#  ('talbanken', Node<sv-ud-train-49#8, det>),
#  ('talbanken', Node<sv-ud-train-49#9, nya>),
#  ('talbanken', Node<sv-ud-train-49#10, systemet>),
#  ('talbanken', Node<sv-ud-train-49#11, att>),
#  ('talbanken', Node<sv-ud-train-49#12, beräkna>),
#  ('talbanken', Node<sv-ud-train-49#13, extra>),
#  ('talbanken', Node<sv-ud-train-49#14, avdrag>),
#  ('talbanken', Node<sv-ud-train-49#15, åberopade>),
#  ('talbanken', Node<sv-ud-train-49#16, finansministern>),
#  ('talbanken', Node<sv-ud-train-49#17, i>),
#  ('talbanken', Node<sv-ud-train-49#18, propositionen>),
#  ('talbanken', Node<sv-ud-train-49#19, till>),
#  ('talbanken', Node<sv-ud-train-49#20, riksdagen>),
#  ('talbanken', Node<sv-ud-train-49#21, följande>),
#  ('talbanken', Node<sv-ud-train-49#22, tabell>),
#  ('talbanken', Node<sv-ud-train-49#23, .>),
#  ('talbanken', Node<sv-ud-train-50#1, Från>),
#  ('talbanken', Node<sv-ud-train-50#2, civil>),
#  ('talbanken', Node<sv-ud-train-50#3, till>),
#  ('talbanken', Node<sv-ud-train-50#4, militär>),
#  ('talbanken', Node<sv-ud-train-51#1, Den>),
#  ('talbanken', Node<sv-ud-train-51#2, här>),
#  ('talbanken', Node<sv-ud-train-51#3, broschyren>),
#  ('talbanken', Node<sv-ud-train-51#4, vill>),
#  ('talbanken', Node<sv-ud-train-51#5, ge>),
#  ('talbanken', Node<sv-ud-train-51#6, dig>),
#  ('talbanken', Node<sv-ud-train-51#7, en>),
#  ('talbanken', Node<sv-ud-train-51#8, bild>),
#  ('talbanken', Node<sv-ud-train-51#9, av>),
#  ('talbanken', Node<sv-ud-train-51#10, vad>),
#  ('talbanken', Node<sv-ud-train-51#11, som>),
#  ('talbanken', Node<sv-ud-train-51#12, händer>),
#  ('talbanken', Node<sv-ud-train-51#13, under>),
#  ('talbanken', Node<sv-ud-train-51#14, din>),
#  ('talbanken', Node<sv-ud-train-51#15, militärutbildning>),
#  ('talbanken', Node<sv-ud-train-51#16, .>),
#  ('talbanken', Node<sv-ud-train-52#1, Läs>),
#  ('talbanken', Node<sv-ud-train-52#2, den>),
#  ('talbanken', Node<sv-ud-train-52#3, och>),
#  ('talbanken', Node<sv-ud-train-52#4, behåll>),
#  ('talbanken', Node<sv-ud-train-52#5, den>),
#  ('talbanken', Node<sv-ud-train-52#6, under>),
#  ('talbanken', Node<sv-ud-train-52#7, utbildningsåret>),
#  ('talbanken', Node<sv-ud-train-52#8, .>),
#  ('talbanken', Node<sv-ud-train-53#1, Inryckning>),
#  ('talbanken', Node<sv-ud-train-54#1, En>),
#  ('talbanken', Node<sv-ud-train-54#2, ny>),
#  ('talbanken', Node<sv-ud-train-54#3, och>),
#  ('talbanken', Node<sv-ud-train-54#4, ovan>),
#  ('talbanken', Node<sv-ud-train-54#5, miljö>),
#  ('talbanken', Node<sv-ud-train-54#6, väntar>),
#  ('talbanken', Node<sv-ud-train-54#7, .>),
#  ('talbanken', Node<sv-ud-train-55#1, Befälet>),
#  ('talbanken', Node<sv-ud-train-55#2, vid>),
#  ('talbanken', Node<sv-ud-train-55#3, ditt>),
#  ('talbanken', Node<sv-ud-train-55#4, förband>),
#  ('talbanken', Node<sv-ud-train-55#5, kommer>),
#  ('talbanken', Node<sv-ud-train-55#6, att>),
#  ('talbanken', Node<sv-ud-train-55#7, introducera>),
#  ('talbanken', Node<sv-ud-train-55#8, dig>),
#  ('talbanken', Node<sv-ud-train-55#9, i>),
#  ('talbanken', Node<sv-ud-train-55#10, den>),
#  ('talbanken', Node<sv-ud-train-55#11, nya>),
#  ('talbanken', Node<sv-ud-train-55#12, miljön>),
#  ('talbanken', Node<sv-ud-train-55#13, och>),
#  ('talbanken', Node<sv-ud-train-55#14, informera>),
#  ('talbanken', Node<sv-ud-train-55#15, dig>),
#  ('talbanken', Node<sv-ud-train-55#16, om>),
#  ('talbanken', Node<sv-ud-train-55#17, verksamheten>),
#  ('talbanken', Node<sv-ud-train-55#18, .>),
#  ('talbanken', Node<sv-ud-train-56#1, Under>),
#  ('talbanken', Node<sv-ud-train-56#2, militärtjänsten>),
#  ('talbanken', Node<sv-ud-train-56#3, har>),
#  ('talbanken', Node<sv-ud-train-56#4, du>),
#  ('talbanken', Node<sv-ud-train-56#5, många>),
#  ('talbanken', Node<sv-ud-train-56#6, skyldigheter>),
#  ('talbanken', Node<sv-ud-train-56#7, ,>),
#  ('talbanken', Node<sv-ud-train-56#8, som>),
#  ('talbanken', Node<sv-ud-train-56#9, berörs>),
#  ('talbanken', Node<sv-ud-train-56#10, på>),
#  ('talbanken', Node<sv-ud-train-56#11, de>),
#  ('talbanken', Node<sv-ud-train-56#12, närmaste>),
#  ('talbanken', Node<sv-ud-train-56#13, sidorna>),
#  ('talbanken', Node<sv-ud-train-56#14, .>),
#  ('talbanken', Node<sv-ud-train-57#1, Samhället>),
#  ('talbanken', Node<sv-ud-train-57#2, har>),
#  ('talbanken', Node<sv-ud-train-57#3, också>),
#  ('talbanken', Node<sv-ud-train-57#4, givit>),
#  ('talbanken', Node<sv-ud-train-57#5, dig>),
#  ('talbanken', Node<sv-ud-train-57#6, en>),
#  ('talbanken', Node<sv-ud-train-57#7, rad>),
#  ('talbanken', Node<sv-ud-train-57#8, förmåner>),
#  ('talbanken', Node<sv-ud-train-57#9, och>),
#  ('talbanken', Node<sv-ud-train-57#10, dessa>),
#  ('talbanken', Node<sv-ud-train-57#11, redovisas>),
#  ('talbanken', Node<sv-ud-train-57#12, längre>),
#  ('talbanken', Node<sv-ud-train-57#13, fram>),
#  ('talbanken', Node<sv-ud-train-57#14, i>),
#  ('talbanken', Node<sv-ud-train-57#15, broschyren>),
#  ('talbanken', Node<sv-ud-train-57#16, .>),
#  ('talbanken', Node<sv-ud-train-58#1, Kasernlivet>),
#  ('talbanken', Node<sv-ud-train-59#1, Den>),
#  ('talbanken', Node<sv-ud-train-59#2, koncentrerade>),
#  ('talbanken', Node<sv-ud-train-59#3, militära>),
#  ('talbanken', Node<sv-ud-train-59#4, utbildning>),
#  ('talbanken', Node<sv-ud-train-59#5, som>),
#  ('talbanken', Node<sv-ud-train-59#6, du>),
#  ('talbanken', Node<sv-ud-train-59#7, får>),
#  ('talbanken', Node<sv-ud-train-59#8, sker>),
#  ('talbanken', Node<sv-ud-train-59#9, av>),
#  ('talbanken', Node<sv-ud-train-59#10, praktiska>),
#  ('talbanken', Node<sv-ud-train-59#11, skäl>),
#  ('talbanken', Node<sv-ud-train-59#12, i>),
#  ('talbanken', Node<sv-ud-train-59#13, en>),
#  ('talbanken', Node<sv-ud-train-59#14, internatförläggning>),
#  ('talbanken', Node<sv-ud-train-59#15, ->),
#  ('talbanken', Node<sv-ud-train-59#16, i>),
#  ('talbanken', Node<sv-ud-train-59#17, kasern>),
#  ('talbanken', Node<sv-ud-train-59#18, .>),
#  ('talbanken', Node<sv-ud-train-60#1, Du>),
#  ('talbanken', Node<sv-ud-train-60#2, skall>),
#  ('talbanken', Node<sv-ud-train-60#3, nämligen>),
#  ('talbanken', Node<sv-ud-train-60#4, inte>),
#  ('talbanken', Node<sv-ud-train-60#5, bara>),
#  ('talbanken', Node<sv-ud-train-60#6, skaffa>),
#  ('talbanken', Node<sv-ud-train-60#7, dig>),
#  ('talbanken', Node<sv-ud-train-60#8, vissa>),
#  ('talbanken', Node<sv-ud-train-60#9, kunskaper>),
#  ('talbanken', Node<sv-ud-train-60#10, ,>),
#  ('talbanken', Node<sv-ud-train-60#11, du>),
#  ('talbanken', Node<sv-ud-train-60#12, skall>),
#  ('talbanken', Node<sv-ud-train-60#13, också>),
#  ('talbanken', Node<sv-ud-train-60#14, lära>),
#  ('talbanken', Node<sv-ud-train-60#15, dig>),
#  ('talbanken', Node<sv-ud-train-60#16, leva>),
#  ('talbanken', Node<sv-ud-train-60#17, ihop>),
#  ('talbanken', Node<sv-ud-train-60#18, med>),
#  ('talbanken', Node<sv-ud-train-60#19, dina>),
#  ('talbanken', Node<sv-ud-train-60#20, kamrater>),
#  ('talbanken', Node<sv-ud-train-60#21, och>),
#  ('talbanken', Node<sv-ud-train-60#22, så>),
#  ('talbanken', Node<sv-ud-train-60#23, småningom>),
#  ('talbanken', Node<sv-ud-train-60#24, sammangjutas>),
#  ('talbanken', Node<sv-ud-train-60#25, med>),
#  ('talbanken', Node<sv-ud-train-60#26, dem>),
#  ('talbanken', Node<sv-ud-train-60#27, till>),
#  ('talbanken', Node<sv-ud-train-60#28, ett>),
#  ('talbanken', Node<sv-ud-train-60#29, förband>),
#  ('talbanken', Node<sv-ud-train-60#30, .>),
#  ('talbanken', Node<sv-ud-train-61#1, Lydnad>),
#  ('talbanken', Node<sv-ud-train-62#1, Krig>),
#  ('talbanken', Node<sv-ud-train-62#2, är>),
#  ('talbanken', Node<sv-ud-train-62#3, hårt>),
#  ('talbanken', Node<sv-ud-train-62#4, och>),
#  ('talbanken', Node<sv-ud-train-62#5, brutalt>),
#  ('talbanken', Node<sv-ud-train-62#6, .>),
#  ('talbanken', Node<sv-ud-train-63#1, Den>),
#  ('talbanken', Node<sv-ud-train-63#2, militära>),
#  ('talbanken', Node<sv-ud-train-63#3, verksamheten>),
#  ('talbanken', Node<sv-ud-train-63#4, har>),
#  ('talbanken', Node<sv-ud-train-63#5, kriget>),
#  ('talbanken', Node<sv-ud-train-63#6, som>),
#  ('talbanken', Node<sv-ud-train-63#7, bakgrund>),
#  ('talbanken', Node<sv-ud-train-63#8, .>),
#  ('talbanken', Node<sv-ud-train-64#1, Det>),
#  ('talbanken', Node<sv-ud-train-64#2, militära>),
#  ('talbanken', Node<sv-ud-train-64#3, livet>),
#  ('talbanken', Node<sv-ud-train-64#4, avviker>),
#  ('talbanken', Node<sv-ud-train-64#5, därför>),
#  ('talbanken', Node<sv-ud-train-64#6, ofta>),
#  ('talbanken', Node<sv-ud-train-64#7, från>),
#  ('talbanken', Node<sv-ud-train-64#8, det>),
#  ('talbanken', Node<sv-ud-train-64#9, civila>),
#  ('talbanken', Node<sv-ud-train-64#10, .>),
#  ('talbanken', Node<sv-ud-train-65#1, Den>),
#  ('talbanken', Node<sv-ud-train-65#2, ovillkorliga>),
#  ('talbanken', Node<sv-ud-train-65#3, och>),
#  ('talbanken', Node<sv-ud-train-65#4, ögonblickliga>),
#  ('talbanken', Node<sv-ud-train-65#5, lydnad>),
#  ('talbanken', Node<sv-ud-train-65#6, som>),
#  ('talbanken', Node<sv-ud-train-65#7, den>),
#  ('talbanken', Node<sv-ud-train-65#8, militära>),
#  ('talbanken', Node<sv-ud-train-65#9, verksamheten>),
#  ('talbanken', Node<sv-ud-train-65#10, kräver>),
#  ('talbanken', Node<sv-ud-train-65#11, ,>),
#  ('talbanken', Node<sv-ud-train-65#12, har>),
#  ('talbanken', Node<sv-ud-train-65#13, också>),
#  ('talbanken', Node<sv-ud-train-65#14, sin>),
#  ('talbanken', Node<sv-ud-train-65#15, motsvarighet>),
#  ('talbanken', Node<sv-ud-train-65#16, i>),
#  ('talbanken', Node<sv-ud-train-65#17, det>),
#  ('talbanken', Node<sv-ud-train-65#18, civila>),
#  ('talbanken', Node<sv-ud-train-65#19, ,>),
#  ('talbanken', Node<sv-ud-train-65#20, t ex>),
#  ('talbanken', Node<sv-ud-train-65#21, på>),
#  ('talbanken', Node<sv-ud-train-65#22, de>),
#  ('talbanken', Node<sv-ud-train-65#23, områden>),
#  ('talbanken', Node<sv-ud-train-65#24, där>),
#  ('talbanken', Node<sv-ud-train-65#25, liv>),
#  ('talbanken', Node<sv-ud-train-65#26, står>),
#  ('talbanken', Node<sv-ud-train-65#27, på>),
#  ('talbanken', Node<sv-ud-train-65#28, spel>),
#  ('talbanken', Node<sv-ud-train-65#29, .>),
#  ('talbanken', Node<sv-ud-train-66#1, Krav>),
#  ('talbanken', Node<sv-ud-train-66#2, på>),
#  ('talbanken', Node<sv-ud-train-66#3, disciplin>),
#  ('talbanken', Node<sv-ud-train-66#4, möter>),
#  ('talbanken', Node<sv-ud-train-66#5, du>),
#  ('talbanken', Node<sv-ud-train-66#6, på>),
#  ('talbanken', Node<sv-ud-train-66#7, de>),
#  ('talbanken', Node<sv-ud-train-66#8, flesta>),
#  ('talbanken', Node<sv-ud-train-66#9, andra>),
#  ('talbanken', Node<sv-ud-train-66#10, områden>),
#  ('talbanken', Node<sv-ud-train-66#11, i>),
#  ('talbanken', Node<sv-ud-train-66#12, samhället>),
#  ('talbanken', Node<sv-ud-train-66#13, .>),
#  ('talbanken', Node<sv-ud-train-67#1, Under>),
#  ('talbanken', Node<sv-ud-train-67#2, militärutbildningen>),
#  ('talbanken', Node<sv-ud-train-67#3, måste>),
#  ('talbanken', Node<sv-ud-train-67#4, du>),
#  ('talbanken', Node<sv-ud-train-67#5, emellertid>),
#  ('talbanken', Node<sv-ud-train-67#6, underordna>),
#  ('talbanken', Node<sv-ud-train-67#7, dig>),
#  ('talbanken', Node<sv-ud-train-67#8, på>),
#  ('talbanken', Node<sv-ud-train-67#9, ett>),
#  ('talbanken', Node<sv-ud-train-67#10, sätt>),
#  ('talbanken', Node<sv-ud-train-67#11, ,>),
#  ('talbanken', Node<sv-ud-train-67#12, som>),
#  ('talbanken', Node<sv-ud-train-67#13, kanske>),
#  ('talbanken', Node<sv-ud-train-67#14, är>),
#  ('talbanken', Node<sv-ud-train-67#15, nytt>),
#  ('talbanken', Node<sv-ud-train-67#16, och>),
#  ('talbanken', Node<sv-ud-train-67#17, besvärande>),
#  ('talbanken', Node<sv-ud-train-67#18, .>),
#  ('talbanken', Node<sv-ud-train-68#1, Men>),
#  ('talbanken', Node<sv-ud-train-68#2, tro>),
#  ('talbanken', Node<sv-ud-train-68#3, inte>),
#  ('talbanken', Node<sv-ud-train-68#4, du>),
#  ('talbanken', Node<sv-ud-train-68#5, skall>),
#  ('talbanken', Node<sv-ud-train-68#6, koppla>),
#  ('talbanken', Node<sv-ud-train-68#7, av>),
#  ('talbanken', Node<sv-ud-train-68#8, din>),
#  ('talbanken', Node<sv-ud-train-68#9, egen>),
#  ('talbanken', Node<sv-ud-train-68#10, tankeverksamhet>),
#  ('talbanken', Node<sv-ud-train-68#11, !>),
#  ('talbanken', Node<sv-ud-train-69#1, Du>),
#  ('talbanken', Node<sv-ud-train-69#2, måste>),
#  ('talbanken', Node<sv-ud-train-69#3, både>),
#  ('talbanken', Node<sv-ud-train-69#4, kunna>),
#  ('talbanken', Node<sv-ud-train-69#5, handla>),
#  ('talbanken', Node<sv-ud-train-69#6, självständigt>),
#  ('talbanken', Node<sv-ud-train-69#7, och>),
#  ('talbanken', Node<sv-ud-train-69#8, lyda>),
#  ('talbanken', Node<sv-ud-train-69#9, för>),
#  ('talbanken', Node<sv-ud-train-69#10, att>),
#  ('talbanken', Node<sv-ud-train-69#11, bli>),
#  ('talbanken', Node<sv-ud-train-69#12, en>),
#  ('talbanken', Node<sv-ud-train-69#13, bra>),
#  ('talbanken', Node<sv-ud-train-69#14, soldat>),
#  ('talbanken', Node<sv-ud-train-69#15, .>),
#  ('talbanken', Node<sv-ud-train-70#1, Under>),
#  ('talbanken', Node<sv-ud-train-70#2, fredsutbildningen>),
#  ('talbanken', Node<sv-ud-train-70#3, framkommer>),
#  ('talbanken', Node<sv-ud-train-70#4, detta>),
#  ('talbanken', Node<sv-ud-train-70#5, särskilt>),
#  ('talbanken', Node<sv-ud-train-70#6, tydligt>),
#  ('talbanken', Node<sv-ud-train-70#7, vid>),
#  ('talbanken', Node<sv-ud-train-70#8, övningar>),
#  ('talbanken', Node<sv-ud-train-70#9, med>),
#  ('talbanken', Node<sv-ud-train-70#10, skarp>),
#  ('talbanken', Node<sv-ud-train-70#11, ammunition>),
#  ('talbanken', Node<sv-ud-train-70#12, .>),
#  ('talbanken', Node<sv-ud-train-71#1, I>),
#  ('talbanken', Node<sv-ud-train-71#2, krig>),
#  ('talbanken', Node<sv-ud-train-71#3, utförs>),
#  ('talbanken', Node<sv-ud-train-71#4, all>),
#  ...]

# %% [markdown]
# # Lemmas

# %%
matches = treebanks.filter(upos='ADJ',
                 func1=lambda node: ((node.lemma.endswith('a') or
                                     node.lemma.endswith('t') or
                                     node.lemma.endswith('as') or
                                     node.lemma.endswith('t') or
                                     node.lemma.endswith('t')) and 
                                     not (node.lemma.endswith('t') and 
                                          node.lemma[-2] in ['k', 's', 'p', 'f']) and
                                     not node.lemma.endswith(':e') and
                                     not node.lemma.endswith(':a')),
                 func2=lambda node: node.feats['VerbForm'] != 'Part').content(lemma=True)

print(len(matches))
print(*matches, sep='\n')
print(len(matches))
# Out:
# 258
# form='absolut'	lemma='absolut'
# form='absoluta'	lemma='absolut'
# form='akut'	lemma='akut'
# form='akuta'	lemma='akut'
# form='alerta'	lemma='alert'
# form='andra'	lemma='andra'
# form='Andra'	lemma='andra'
# form='annorlunda'	lemma='annorlunda'
# form='arrogant'	lemma='arrogant'
# form='bastant'	lemma='bastant'
# form='bekant'	lemma='bekant'
# form='bekanta'	lemma='bekant'
# form='betalt'	lemma='betala'
# form='bevänt'	lemma='bevänt'
# form='bjärta'	lemma='bjärt'
# form='Blotta'	lemma='blott'
# form='blotta'	lemma='blott'
# form='blöt'	lemma='blöt'
# form='bosatta'	lemma='bosatt'
# form='bra'	lemma='bra'
# form='Bra'	lemma='bra'
# form='brant'	lemma='brant'
# form='brunrosa'	lemma='brunrosa'
# form='bäst'	lemma='bra'
# form='bästa'	lemma='bra'
# form='Bästa'	lemma='bra'
# form='bäste'	lemma='bra'
# form='Bättre'	lemma='bra'
# form='bättre'	lemma='bra'
# form='båda'	lemma='båda'
# form='Båda'	lemma='båda'
# form='desamma'	lemma='desamma'
# form='desperat'	lemma='desperat'
# form='desperata'	lemma='desperat'
# form='diskret'	lemma='diskret'
# form='djävulsbesatta'	lemma='djävulsbesatt'
# form='elegant'	lemma='elegant'
# form='eleganta'	lemma='elegant'
# form='ena'	lemma='ena'
# form='enahanda'	lemma='enahanda'
# form='enda'	lemma='enda'
# form='Enda'	lemma='enda'
# form='ende'	lemma='enda'
# form='ene'	lemma='ena'
# form='enstaka'	lemma='enstaka'
# form='extra'	lemma='extra'
# form='extravagant'	lemma='extravagant'
# form='fet'	lemma='fet'
# form='feta'	lemma='fet'
# form='fixa'	lemma='fixa'
# form='flera'	lemma='flera'
# form='Flera'	lemma='flera'
# form='fortsatta'	lemma='fortsatt'
# form='framtida'	lemma='framtida'
# form='fullsatt'	lemma='fullsatt'
# form='fyrbenta'	lemma='fyrbent'
# form='föga'	lemma='föga'
# form='förment'	lemma='förment'
# form='förra'	lemma='förra'
# form='Förra'	lemma='förra'
# form='första'	lemma='första'
# form='Första'	lemma='första'
# form='förtida'	lemma='förtida'
# form='Förtida'	lemma='förtida'
# form='gladlynt'	lemma='gladlynt'
# form='glädjevitt'	lemma='glädjevit'
# form='grisfet'	lemma='grisfet'
# form='gråvita'	lemma='gråvit'
# form='halte'	lemma='halt'
# form='het'	lemma='het'
# form='heta'	lemma='het'
# form='Hett'	lemma='het'
# form='hett'	lemma='het'
# form='icke-vita'	lemma='icke-vit'
# form='illa'	lemma='illa'
# form='implicita'	lemma='implicit'
# form='Independent'	lemma='independent'
# form='indifferent'	lemma='indifferent'
# form='indifferenta'	lemma='indifferent'
# form='indiskret'	lemma='indiskret'
# form='inkompetenta'	lemma='inkompetent'
# form='intelligent'	lemma='intelligent'
# form='intelligenta'	lemma='intelligent'
# form='Intermittent'	lemma='Intermittent'
# form='intressant'	lemma='intressant'
# form='Intressant'	lemma='intressant'
# form='intressanta'	lemma='intressant'
# form='intressantare'	lemma='intressant'
# form='irrelevanta'	lemma='irrelevant'
# form='jäkla'	lemma='jäkla'
# form='jättebra'	lemma='jättebra'
# form='jävla'	lemma='jävla'
# form='knäckt'	lemma='knäcka'
# form='kokhett'	lemma='kokhet'
# form='kompetent'	lemma='kompetent'
# form='kompetenta'	lemma='kompetent'
# form='komplett'	lemma='komplett'
# form='konkret'	lemma='konkret'
# form='konkreta'	lemma='konkret'
# form='Konkreta'	lemma='konkret'
# form='konsekvent'	lemma='konsekvent'
# form='konsekventa'	lemma='konsekvent'
# form='konstant'	lemma='konstant'
# form='konstanta'	lemma='konstant'
# form='korpsvart'	lemma='korpsvart'
# form='kort'	lemma='kort'
# form='korta'	lemma='kort'
# form='kortare'	lemma='kort'
# form='kortaste'	lemma='kort'
# form='kortsynt'	lemma='kortsynt'
# form='kortväxt'	lemma='kortväxt'
# form='krigströtta'	lemma='krigstrött'
# form='kvitt'	lemma='kvitt'
# form='laga'	lemma='laga'
# form='latenta'	lemma='latent'
# form='laxrosa'	lemma='laxrosa'
# form='lika'	lemma='lika'
# form='lila'	lemma='lila'
# form='lodrät'	lemma='lodrät'
# form='lyckade'	lemma='lyckas'
# form='lätt'	lemma='lätt'
# form='lätta'	lemma='lätt'
# form='Lätta'	lemma='lätt'
# form='lättare'	lemma='lätt'
# form='lättast'	lemma='lätt'
# form='långväga'	lemma='långväga'
# form='matta'	lemma='matt'
# form='medeltida'	lemma='medeltida'
# form='mellersta'	lemma='mellersta'
# form='mer'	lemma='mycket'
# form='Mer'	lemma='mycket'
# form='mera'	lemma='mycket'
# form='mera'	lemma='mera'
# form='militant'	lemma='militant'
# form='mjölkvitt'	lemma='mjölkvit'
# form='moderat'	lemma='moderat'
# form='moderata'	lemma='moderat'
# form='morgontrötta'	lemma='morgontrött'
# form='motsatta'	lemma='motsatt'
# form='mycket'	lemma='mycket'
# form='mätta'	lemma='mätt'
# form='många'	lemma='många'
# form='Många'	lemma='många'
# form='nedersta'	lemma='nedersta'
# form='noga'	lemma='noga'
# form='nordvästra'	lemma='nordvästra'
# form='nordöstra'	lemma='nordöstra'
# form='Norra'	lemma='norra'
# form='norra'	lemma='norra'
# form='nutida'	lemma='nutida'
# form='nära'	lemma='nära'
# form='närmare'	lemma='nära'
# form='närmast'	lemma='nära'
# form='närmaste'	lemma='nära'
# form='Närmaste'	lemma='nära'
# form='närsynt'	lemma='närsynt'
# form='nästa'	lemma='nästa'
# form='Nästa'	lemma='nästa'
# form='nött'	lemma='nött'
# form='obekant'	lemma='obekant'
# form='ointelligent'	lemma='ointelligent'
# form='ointressant'	lemma='ointressant'
# form='omaka'	lemma='omaka'
# form='orätt'	lemma='orätt'
# form='permanent'	lemma='permanent'
# form='permanenta'	lemma='permanent'
# form='permanente'	lemma='permanent'
# form='platt'	lemma='platt'
# form='platta'	lemma='platt'
# form='plattare'	lemma='platt'
# form='privat'	lemma='privat'
# form='privata'	lemma='privat'
# form='ringa'	lemma='ringa'
# form='rosa'	lemma='rosa'
# form='rät'	lemma='rät'
# form='räta'	lemma='rät'
# form='rätt'	lemma='rätt'
# form='rätta'	lemma='rätt'
# form='Sakta'	lemma='sakta'
# form='salt'	lemma='salt'
# form='samma'	lemma='samma'
# form='sammansatta'	lemma='sammansatt'
# form='samtida'	lemma='samtida'
# form='satte'	lemma='satt'
# form='separat'	lemma='separat'
# form='separata'	lemma='separat'
# form='sista'	lemma='sista'
# form='Sista'	lemma='sista'
# form='siste'	lemma='sista'
# form='slut'	lemma='slut'
# form='släta'	lemma='slät'
# form='slätnötta'	lemma='slätnött'
# form='smart'	lemma='smart'
# form='smarta'	lemma='smart'
# form='smartare'	lemma='smart'
# form='snökrönta'	lemma='snökrönt'
# form='snövit'	lemma='snövit'
# form='snövita'	lemma='snövit'
# form='Stilla'	lemma='stilla'
# form='stilla'	lemma='stilla'
# form='stolt'	lemma='stolt'
# form='stolte'	lemma='stolt'
# form='styvsint'	lemma='styvsint'
# form='svart'	lemma='svart'
# form='Svart'	lemma='svart'
# form='svarta'	lemma='svart'
# form='Svarta'	lemma='svart'
# form='svartas'	lemma='svart'
# form='svarte'	lemma='svart'
# form='sydvästra'	lemma='sydvästra'
# form='sydöstra'	lemma='sydöstra'
# form='sysselsatta'	lemma='sysselsatt'
# form='sällsynt'	lemma='sällsynt'
# form='sällsynta'	lemma='sällsynt'
# form='södra'	lemma='södra'
# form='Södra'	lemma='södra'
# form='söt'	lemma='söt'
# form='sött'	lemma='söt'
# form='toleranta'	lemma='tolerant'
# form='tolerantare'	lemma='tolerant'
# form='trebent'	lemma='trebent'
# form='trivsamma'	lemma='trivsamma'
# form='trött'	lemma='trött'
# form='trötta'	lemma='trött'
# form='tungsint'	lemma='tungsint'
# form='tät'	lemma='tät'
# form='täta'	lemma='tät'
# form='tätast'	lemma='tät'
# form='tätt'	lemma='tät'
# form='udda'	lemma='udda'
# form='uppblötta'	lemma='uppblött'
# form='upprätta'	lemma='upprätt'
# form='urarva'	lemma='urarva'
# form='utsatta'	lemma='utsatt'
# form='vattentäta'	lemma='vattentät'
# form='vidsynta'	lemma='vidsynt'
# form='vinkelräta'	lemma='vinkelrät'
# form='vit'	lemma='vit'
# form='Vit'	lemma='vit'
# form='vita'	lemma='vit'
# form='Vita'	lemma='vit'
# form='vitas'	lemma='vit'
# form='vitaste'	lemma='vit'
# form='vite'	lemma='vit'
# form='vitt'	lemma='vit'
# form='välbekant'	lemma='välbekant'
# form='välbekanta'	lemma='välbekant'
# form='välskött'	lemma='välskött'
# form='välskötta'	lemma='välskött'
# form='Västra'	lemma='västra'
# form='västra'	lemma='västra'
# form='vågrät'	lemma='vågrät'
# form='våta'	lemma='våt'
# form='vått'	lemma='våt'
# form='yra'	lemma='yra'
# form='äkta'	lemma='äkta'
# form='östra'	lemma='östra'
# form='översatta'	lemma='översatt'
# 258

# %%
matches = treebanks.filter(upos='ADJ',
                           VerbForm='Part',
                           func1=lambda node: node.lemma.endswith('a')).content(lemma=True,
                                                                                feats=True)

print(len(matches))
print(*matches, sep='\n')
print(len(matches))
# Out:
# 0
#
# 0

# %%
treebanks.filter(upos='ADJ',
                 func1=lambda tok: '_' in tok.lemma).content(feats=True,
                                                                        lemma=True)
# Out:
# ["form='s k'\tlemma='så_kallad'\tfeats='Abbr=Yes'\t",
#  "form='s.k.'\tlemma='så_kallad'\tfeats='Abbr=Yes'\t"]

# %%
treebanks.filter(form='mellersta').content(text=True, lemma=True)
# Out:
# ["form='mellersta'\tlemma='mellersta'\ttext='De är koncentrerade till södra och mellersta Sveriges industribygder.'\t"]
